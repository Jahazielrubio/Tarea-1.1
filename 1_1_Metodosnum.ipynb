# %%
#   Codigo que implementa un esquema numerico
#   para determinar la precision de una maquina
#
#           Autor:
#  Jahaziel Gabriel Rubio Pech
#   jahazielpech9@gmail.com
#   Version 1.0 : 13/02/2025
#

import numpy as np

epsilon = 1.0
iteracion = 2
while 1.0 + epsilon != 1.0:
    epsilon /= 2
    iteracion = iteracion + 1
    print(f"Iteracion: {iteracion}, Precisión de máquina: {epsilon}")

epsilon *= 2
print(f"Precisión de máquina: {epsilon}")
# Out:
# Iteracion: 3, Precisión de máquina: 0.5
# Iteracion: 4, Precisión de máquina: 0.25
# Iteracion: 5, Precisión de máquina: 0.125
# Iteracion: 6, Precisión de máquina: 0.0625
# Iteracion: 7, Precisión de máquina: 0.03125
# Iteracion: 8, Precisión de máquina: 0.015625
# Iteracion: 9, Precisión de máquina: 0.0078125
# Iteracion: 10, Precisión de máquina: 0.00390625
# Iteracion: 11, Precisión de máquina: 0.001953125
# Iteracion: 12, Precisión de máquina: 0.0009765625
# Iteracion: 13, Precisión de máquina: 0.00048828125
# Iteracion: 14, Precisión de máquina: 0.000244140625
# Iteracion: 15, Precisión de máquina: 0.0001220703125
# Iteracion: 16, Precisión de máquina: 6.103515625e-05
# Iteracion: 17, Precisión de máquina: 3.0517578125e-05
# Iteracion: 18, Precisión de máquina: 1.52587890625e-05
# Iteracion: 19, Precisión de máquina: 7.62939453125e-06
# Iteracion: 20, Precisión de máquina: 3.814697265625e-06
# Iteracion: 21, Precisión de máquina: 1.9073486328125e-06
# Iteracion: 22, Precisión de máquina: 9.5367431640625e-07
# Iteracion: 23, Precisión de máquina: 4.76837158203125e-07
# Iteracion: 24, Precisión de máquina: 2.384185791015625e-07
# Iteracion: 25, Precisión de máquina: 1.1920928955078125e-07
# Iteracion: 26, Precisión de máquina: 5.960464477539063e-08
# Iteracion: 27, Precisión de máquina: 2.9802322387695312e-08
# Iteracion: 28, Precisión de máquina: 1.4901161193847656e-08
# Iteracion: 29, Precisión de máquina: 7.450580596923828e-09
# Iteracion: 30, Precisión de máquina: 3.725290298461914e-09
# Iteracion: 31, Precisión de máquina: 1.862645149230957e-09
# Iteracion: 32, Precisión de máquina: 9.313225746154785e-10
# Iteracion: 33, Precisión de máquina: 4.656612873077393e-10
# Iteracion: 34, Precisión de máquina: 2.3283064365386963e-10
# Iteracion: 35, Precisión de máquina: 1.1641532182693481e-10
# Iteracion: 36, Precisión de máquina: 5.820766091346741e-11
# Iteracion: 37, Precisión de máquina: 2.9103830456733704e-11
# Iteracion: 38, Precisión de máquina: 1.4551915228366852e-11
# Iteracion: 39, Precisión de máquina: 7.275957614183426e-12
# Iteracion: 40, Precisión de máquina: 3.637978807091713e-12
# Iteracion: 41, Precisión de máquina: 1.8189894035458565e-12
# Iteracion: 42, Precisión de máquina: 9.094947017729282e-13
# Iteracion: 43, Precisión de máquina: 4.547473508864641e-13
# Iteracion: 44, Precisión de máquina: 2.2737367544323206e-13
# Iteracion: 45, Precisión de máquina: 1.1368683772161603e-13
# Iteracion: 46, Precisión de máquina: 5.684341886080802e-14
# Iteracion: 47, Precisión de máquina: 2.842170943040401e-14
# Iteracion: 48, Precisión de máquina: 1.4210854715202004e-14
# Iteracion: 49, Precisión de máquina: 7.105427357601002e-15
# Iteracion: 50, Precisión de máquina: 3.552713678800501e-15
# Iteracion: 51, Precisión de máquina: 1.7763568394002505e-15
# Iteracion: 52, Precisión de máquina: 8.881784197001252e-16
# Iteracion: 53, Precisión de máquina: 4.440892098500626e-16
# Iteracion: 54, Precisión de máquina: 2.220446049250313e-16
# Iteracion: 55, Precisión de máquina: 1.1102230246251565e-16
# Precisión de máquina: 2.220446049250313e-16

# %%
#   Codigo que implementa un esquema numerico
#   para determinar la aproximacion de Leibniz
#
#      Jahaziel Gabriel Rubio Pech
#   jahazielpech9@gmail.com
#   Version 1.0 : 13/02/2025
#

import numpy as np
import matplotlib.pyplot as plt

def leibniz_pi(n):
    return 4 * sum((-1)**k / (2*k + 1) for k in range(n))

true_pi = np.pi
N_values = [20, 200, 2000, 20000]
errors_abs = []
errors_rel = []
errors_sq = []

for N in N_values:
    approx_pi = leibniz_pi(N)
    error_abs = abs(true_pi - approx_pi)
    error_rel = error_abs / true_pi
    error_sq = error_abs**2
    errors_abs.append(error_abs)
    errors_rel.append(error_rel)
    errors_sq.append(error_sq)
    print(f"N={N}: Error absoluto={error_abs}, Error relativo={error_rel}, Error cuadratico={error_sq}")

plt.figure()
plt.plot(N_values, errors_abs, label='Error absoluto', marker='o')
plt.plot(N_values, errors_rel, label='Error relativo', marker='s')
plt.plot(N_values, errors_sq, label='Error cuadratico', marker='^')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('N')
plt.ylabel('Error')
plt.legend()
plt.title('Errores en la aproximación de pi')
plt.show()
# Out:
# N=20: Error absoluto=0.04996884692195325, Error relativo=0.015905577976462196, Error cuadratico=0.0024968856627095963
# N=200: Error absoluto=0.004999968750976969, Error relativo=0.001591539484045989, Error cuadratico=2.4999687510746188e-05
# N=2000: Error absoluto=0.0004999999687518297, Error relativo=0.0001591549331452938, Error cuadratico=2.499999687518307e-07
# N=20000: Error absoluto=4.999999996835314e-05, Error relativo=1.5915494299116025e-05, Error cuadratico=2.4999999968353137e-09

# %%
#   Codigo que implementa el calculo de errores
#   en operaciones numericas
#
#           Autor:
#   Jahaziel Gabriel Rubio Pech
#   jahazielpech9@gmail.com
#   Version 1.0 : 13/02/2025
#

def calcular_errores(x, y, valor_real):
    diferencia = x - y
    error_abs = abs(valor_real - diferencia)
    error_rel = error_abs / abs(valor_real)
    error_pct = error_rel * 100
    print(f"Diferencia: {diferencia}")
    print(f"Error absoluto: {error_abs}")
    print(f"Error relativo: {error_rel}")
    print(f"Error porcentual: {error_pct}%")
    return error_abs, error_rel

valores = [(2.0000001, 2.0000000, 0.0000002), (2.000000000000001, 2.000000000000000, 0.000000000000002)]

for x, y, real in valores:
    print(f"\nPara x={x}, y={y}:")
    calcular_errores(x, y, real)
# Out:
# Para x=2.0000001, y=2.0:
# Diferencia: 9.999999983634211e-08
# Error absoluto: 1.0000000016365788e-07
# Error relativo: 0.5000000008182894
# Error porcentual: 50.000000081828944%
#
# Para x=2.000000000000001, y=2.0:
# Diferencia: 8.881784197001252e-16
# Error absoluto: 1.111821580299875e-15
# Error relativo: 0.5559107901499374
# Error porcentual: 55.59107901499374%
